# %%
# Implement Hierarchical Clustering

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %%
# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# %%
# Standardize the features (mean=0 and variance=1)
X_std = StandardScaler().fit_transform(X)

# Perform hierarchical clustering
linkage_matrix = linkage(X_std, method='ward')

# %%
# Plot the dendrogram
plt.figure(figsize=(12, 8))
dendrogram(linkage_matrix, labels=y, leaf_rotation=90, leaf_font_size=12)
plt.title('Hierarchical Clustering Dendrogram (Iris)')
plt.xlabel('Data Point Index')
plt.ylabel('Distance')
plt.show()

# %%
# Visualize the clustered data using a heatmap
sns.clustermap(X_std, col_cluster=False, row_cluster=True, cmap="viridis",
               row_colors=sns.color_palette("viridis", as_cmap=True)(y))
plt.show()
